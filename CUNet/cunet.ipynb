# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import layers
import numpy as np
from tqdm import tqdm
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
images_dir = '/content/drive/MyDrive/dataset/images'
masks_dir = '/content/drive/MyDrive/dataset/masks'

# %%
def gelu(x):
  return 0.5 * x * (1 + tf.math.erf(x / tf.sqrt(2.0)))

def ConvMixer(x,n_filters):
  depthwise_conv = tf.keras.layers.DepthwiseConv2D(kernel_size=(7, 7), padding='same')(x)
  gelu_activation = tf.keras.layers.Lambda(lambda y: gelu(y))(depthwise_conv)
  z_ = tf.keras.layers.BatchNormalization()(gelu_activation)
  z_input = tf.keras.layers.Add()([z_,x])
  pointwise_conv = tf.keras.layers.Conv2D(filters=64, kernel_size=(1, 1), activation=None, padding='same')(z_input)
  gelu_activation_2 = tf.keras.layers.Lambda(lambda y: gelu(y))(pointwise_conv)
  output_layer = tf.keras.layers.BatchNormalization()(gelu_activation_2)
  return output_layer

def conv_convmixer(x, n_filters):
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = ConvMixer(x,n_filters)
  x = ConvMixer(x,n_filters)
  p = layers.MaxPool2D(2)(x)
  p = layers.Dropout(0.3)(p)
  return x,p

def double_conv_block(x, n_filters):
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  return x

def upsample_block(x, conv_features, n_filters):
  x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
  x = layers.concatenate([x, conv_features])
  x = layers.Dropout(0.3)(x)
  x = double_conv_block(x, n_filters)
  return x

def bottle(x,n_filters):
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = ConvMixer(x,n_filters)
  x = ConvMixer(x,n_filters)
  return x

# %%
def build_cunet_model():
  inputs = layers.Input(shape=(384, 384,3))
  f1, p1 = conv_convmixer(inputs, 64)
  f2, p2 = conv_convmixer(p1, 128)
  f3, p3 = conv_convmixer(p2, 256)
  f4, p4 = conv_convmixer(p3, 512)

  bottleneck = bottle(p4, 1024)

  u6 = upsample_block(bottleneck, f4, 512)
  u7 = upsample_block(u6, f3, 256)
  u8 = upsample_block(u7, f2, 128)
  u9 = upsample_block(u8, f1, 64)

  outputs = layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u9)

  cunet_model = tf.keras.Model(inputs, outputs, name="CU-Net")

  return cunet_model

# %%
def dice_coefficient(y_true, y_pred):
  smooth = 1e-6  # Smoothing factor to avoid division by zero
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
  dice = (2. * intersection + smooth) / (union + smooth)
  return dice

def iou(y_true, y_pred):
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
  smooth = 1e-6
  return (intersection + smooth) / (union - intersection + smooth)

def precision(y_true, y_pred):
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
  smooth = 1e-6
  return (intersection + smooth) / (tf.reduce_sum(y_pred)+ smooth)

def recall(y_true, y_pred):
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
  smooth = 1e-6
  return (intersection + smooth) / (tf.reduce_sum(y_true)+ smooth)

# %%
cunet_model = build_cunet_model()
cunet_model.compile(optimizer=tf.keras.optimizers.Adam(),
                   loss=tf.keras.losses.BinaryCrossentropy(),
                   metrics=["accuracy", dice_coefficient, iou, precision, recall])

# %%
tf.keras.utils.plot_model(cunet_model, show_shapes=True, expand_nested=True, dpi=64)

# %%
def resize(input_image, input_mask):
   input_image = tf.image.resize(input_image, (384, 384), method="nearest")
   input_mask = tf.image.resize(input_mask, (384, 384), method="nearest")
   return input_image, input_mask

def augment(input_image, input_mask):
   if tf.random.uniform(()) > 0.5:
       # Random flipping of the image and mask
       input_image = tf.image.flip_left_right(input_image)
       input_mask = tf.image.flip_left_right(input_mask)
   return input_image, input_mask

def normalize(input_image, input_mask):
   input_image = tf.cast(input_image, tf.float32) / 255.0
   input_mask -= 255
   return input_image, input_mask

# %%
def load_image_and_mask(image_file, mask_file):
    image = tf.io.read_file(image_file)
    image = tf.image.decode_jpeg(image, channels=3)
    mask = tf.io.read_file(mask_file)
    mask = tf.image.decode_png(mask, channels=1)
    return image, mask

def load_image_train(image_file, mask_file):
    input_image, input_mask = load_image_and_mask(image_file, mask_file)
    input_image, input_mask = resize(input_image, input_mask)
    input_image, input_mask = augment(input_image, input_mask)
    input_image, input_mask = normalize(input_image, input_mask)
    return input_image, input_mask

def load_image_test(image_file, mask_file):
    input_image, input_mask = load_image_and_mask(image_file, mask_file)
    input_image, input_mask = resize(input_image, input_mask)
    input_image, input_mask = normalize(input_image, input_mask)
    return input_image, input_mask

# %%
image_files = sorted([os.path.join(images_dir, filename) for filename in os.listdir(images_dir)])
mask_files = sorted([os.path.join(masks_dir, filename) for filename in os.listdir(masks_dir)])

# 80:20 train:test ratio
split = int(0.2 * len(image_files))

train_dataset = tf.data.Dataset.from_tensor_slices((image_files[split:], mask_files[split:]))
train_dataset = train_dataset.map(load_image_train, num_parallel_calls=tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((image_files[:split], mask_files[:split]))
test_dataset = test_dataset.map(load_image_test, num_parallel_calls=tf.data.AUTOTUNE)

print("Number of training samples:", len(train_dataset))
print("Number of testing samples:", len(test_dataset))
# Out:
# Number of training samples: 962
# Number of testing samples: 240

# %%
BATCH_SIZE = 12
BUFFER_SIZE = 150
train_batches = train_dataset.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
train_batches = train_batches.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
validation_batches = test_dataset.batch(BATCH_SIZE)
test_batches = test_dataset.batch(BATCH_SIZE)

# %%
def display(display_list):
 plt.figure(figsize=(15, 15))

 title = ["Input Image", "True Mask", "Predicted Mask"]

 for i in range(len(display_list)):
   plt.subplot(1, len(display_list), i+1)
   plt.title(title[i])
   plt.imshow(tf.keras.utils.array_to_img(display_list[i]))
   plt.axis("off")
 plt.show()

sample_batch = next(iter(train_batches))
random_index = np.random.choice(sample_batch[0].shape[0])
sample_image, sample_mask = sample_batch[0][random_index], sample_batch[1][random_index]
# print(sample_image.shape)
display([sample_image, sample_mask])

# %%
NUM_EPOCHS = 30
TRAIN_LENGTH = len(train_dataset)
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE
TEST_LENTH = len(test_dataset)
VALIDATION_STEPS = TEST_LENTH // BATCH_SIZE
model_history = cunet_model.fit(train_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                              validation_data=test_batches)
# Out:
# Epoch 1/25
# 80/80 [==============================] - 625s 8s/step - loss: 0.4857 - accuracy: 0.8297 - dice_coefficient: 0.8190 - iou: 0.6959 - precision: 0.8440 - recall: 0.7996 - val_loss: 0.4021 - val_accuracy: 0.8247 - val_dice_coefficient: 0.8498 - val_iou: 0.7393 - val_precision: 0.8400 - val_recall: 0.8613
# Epoch 2/25
# 80/80 [==============================] - 27s 242ms/step - loss: 0.3065 - accuracy: 0.8675 - dice_coefficient: 0.8823 - iou: 0.7916 - precision: 0.8869 - recall: 0.8804 - val_loss: 0.2518 - val_accuracy: 0.8800 - val_dice_coefficient: 0.9014 - val_iou: 0.8208 - val_precision: 0.8839 - val_recall: 0.9204
# Epoch 3/25
# 80/80 [==============================] - 19s 242ms/step - loss: 0.2202 - accuracy: 0.9065 - dice_coefficient: 0.9188 - iou: 0.8502 - precision: 0.9186 - recall: 0.9200 - val_loss: 0.1979 - val_accuracy: 0.9178 - val_dice_coefficient: 0.9203 - val_iou: 0.8525 - val_precision: 0.9264 - val_recall: 0.9148
# Epoch 4/25
# 80/80 [==============================] - 19s 242ms/step - loss: 0.2159 - accuracy: 0.9107 - dice_coefficient: 0.9220 - iou: 0.8556 - precision: 0.9211 - recall: 0.9242 - val_loss: 0.2248 - val_accuracy: 0.8995 - val_dice_coefficient: 0.9207 - val_iou: 0.8534 - val_precision: 0.8912 - val_recall: 0.9530
# Epoch 5/25
# 80/80 [==============================] - 19s 242ms/step - loss: 0.2041 - accuracy: 0.9125 - dice_coefficient: 0.9245 - iou: 0.8598 - precision: 0.9245 - recall: 0.9260 - val_loss: 0.2107 - val_accuracy: 0.9160 - val_dice_coefficient: 0.9351 - val_iou: 0.8785 - val_precision: 0.9087 - val_recall: 0.9638
# Epoch 6/25
# 80/80 [==============================] - 20s 244ms/step - loss: 0.1867 - accuracy: 0.9218 - dice_coefficient: 0.9319 - iou: 0.8727 - precision: 0.9324 - recall: 0.9323 - val_loss: 0.1938 - val_accuracy: 0.9172 - val_dice_coefficient: 0.9257 - val_iou: 0.8620 - val_precision: 0.9096 - val_recall: 0.9431
# Epoch 7/25
# 80/80 [==============================] - 22s 278ms/step - loss: 0.1771 - accuracy: 0.9255 - dice_coefficient: 0.9356 - iou: 0.8792 - precision: 0.9364 - recall: 0.9356 - val_loss: 0.1771 - val_accuracy: 0.9269 - val_dice_coefficient: 0.9382 - val_iou: 0.8840 - val_precision: 0.9211 - val_recall: 0.9566
# Epoch 8/25
# 80/80 [==============================] - 20s 245ms/step - loss: 0.1688 - accuracy: 0.9293 - dice_coefficient: 0.9388 - iou: 0.8849 - precision: 0.9387 - recall: 0.9396 - val_loss: 0.1718 - val_accuracy: 0.9262 - val_dice_coefficient: 0.9305 - val_iou: 0.8703 - val_precision: 0.9269 - val_recall: 0.9347
# Epoch 9/25
# 80/80 [==============================] - 19s 235ms/step - loss: 0.1613 - accuracy: 0.9319 - dice_coefficient: 0.9415 - iou: 0.8897 - precision: 0.9415 - recall: 0.9421 - val_loss: 0.1821 - val_accuracy: 0.9235 - val_dice_coefficient: 0.9378 - val_iou: 0.8833 - val_precision: 0.9138 - val_recall: 0.9638
# Epoch 10/25
# 80/80 [==============================] - 19s 235ms/step - loss: 0.1539 - accuracy: 0.9355 - dice_coefficient: 0.9442 - iou: 0.8944 - precision: 0.9439 - recall: 0.9449 - val_loss: 0.1562 - val_accuracy: 0.9384 - val_dice_coefficient: 0.9464 - val_iou: 0.8987 - val_precision: 0.9367 - val_recall: 0.9570
# Epoch 11/25
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1545 - accuracy: 0.9356 - dice_coefficient: 0.9440 - iou: 0.8942 - precision: 0.9439 - recall: 0.9448 - val_loss: 0.1653 - val_accuracy: 0.9356 - val_dice_coefficient: 0.9485 - val_iou: 0.9023 - val_precision: 0.9311 - val_recall: 0.9672
# Epoch 12/25
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1454 - accuracy: 0.9397 - dice_coefficient: 0.9468 - iou: 0.8992 - precision: 0.9473 - recall: 0.9468 - val_loss: 0.1660 - val_accuracy: 0.9359 - val_dice_coefficient: 0.9481 - val_iou: 0.9017 - val_precision: 0.9287 - val_recall: 0.9690
# Epoch 13/25
# 80/80 [==============================] - 20s 249ms/step - loss: 0.1488 - accuracy: 0.9380 - dice_coefficient: 0.9461 - iou: 0.8980 - precision: 0.9459 - recall: 0.9469 - val_loss: 0.1518 - val_accuracy: 0.9373 - val_dice_coefficient: 0.9406 - val_iou: 0.8882 - val_precision: 0.9323 - val_recall: 0.9496
# Epoch 14/25
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1398 - accuracy: 0.9420 - dice_coefficient: 0.9493 - iou: 0.9037 - precision: 0.9490 - recall: 0.9499 - val_loss: 0.1586 - val_accuracy: 0.9391 - val_dice_coefficient: 0.9495 - val_iou: 0.9042 - val_precision: 0.9339 - val_recall: 0.9662
# Epoch 15/25
# 80/80 [==============================] - 22s 280ms/step - loss: 0.1398 - accuracy: 0.9427 - dice_coefficient: 0.9494 - iou: 0.9038 - precision: 0.9489 - recall: 0.9503 - val_loss: 0.1477 - val_accuracy: 0.9404 - val_dice_coefficient: 0.9448 - val_iou: 0.8957 - val_precision: 0.9466 - val_recall: 0.9435
# Epoch 16/25
# 80/80 [==============================] - 19s 237ms/step - loss: 0.1321 - accuracy: 0.9453 - dice_coefficient: 0.9520 - iou: 0.9084 - precision: 0.9523 - recall: 0.9520 - val_loss: 0.1579 - val_accuracy: 0.9402 - val_dice_coefficient: 0.9489 - val_iou: 0.9032 - val_precision: 0.9318 - val_recall: 0.9673
# Epoch 17/25
# 80/80 [==============================] - 20s 254ms/step - loss: 0.1216 - accuracy: 0.9497 - dice_coefficient: 0.9557 - iou: 0.9153 - precision: 0.9555 - recall: 0.9561 - val_loss: 0.1376 - val_accuracy: 0.9460 - val_dice_coefficient: 0.9549 - val_iou: 0.9141 - val_precision: 0.9503 - val_recall: 0.9602
# Epoch 18/25
# 80/80 [==============================] - 20s 244ms/step - loss: 0.1129 - accuracy: 0.9531 - dice_coefficient: 0.9590 - iou: 0.9214 - precision: 0.9593 - recall: 0.9590 - val_loss: 0.1439 - val_accuracy: 0.9451 - val_dice_coefficient: 0.9561 - val_iou: 0.9161 - val_precision: 0.9542 - val_recall: 0.9584
# Epoch 19/25
# 80/80 [==============================] - 20s 252ms/step - loss: 0.1478 - accuracy: 0.9393 - dice_coefficient: 0.9458 - iou: 0.8975 - precision: 0.9458 - recall: 0.9466 - val_loss: 0.1544 - val_accuracy: 0.9361 - val_dice_coefficient: 0.9377 - val_iou: 0.8830 - val_precision: 0.9507 - val_recall: 0.9256
# Epoch 20/25
# 80/80 [==============================] - 19s 239ms/step - loss: 0.1258 - accuracy: 0.9476 - dice_coefficient: 0.9548 - iou: 0.9136 - precision: 0.9551 - recall: 0.9547 - val_loss: 0.1461 - val_accuracy: 0.9417 - val_dice_coefficient: 0.9485 - val_iou: 0.9023 - val_precision: 0.9587 - val_recall: 0.9391
# Epoch 21/25
# 80/80 [==============================] - 19s 241ms/step - loss: 0.1155 - accuracy: 0.9517 - dice_coefficient: 0.9582 - iou: 0.9198 - precision: 0.9585 - recall: 0.9581 - val_loss: 0.1387 - val_accuracy: 0.9483 - val_dice_coefficient: 0.9587 - val_iou: 0.9208 - val_precision: 0.9532 - val_recall: 0.9647
# Epoch 22/25
# 80/80 [==============================] - 19s 241ms/step - loss: 0.1104 - accuracy: 0.9548 - dice_coefficient: 0.9604 - iou: 0.9238 - precision: 0.9604 - recall: 0.9606 - val_loss: 0.1387 - val_accuracy: 0.9467 - val_dice_coefficient: 0.9551 - val_iou: 0.9144 - val_precision: 0.9515 - val_recall: 0.9593
# Epoch 23/25
# 80/80 [==============================] - 19s 243ms/step - loss: 0.1065 - accuracy: 0.9560 - dice_coefficient: 0.9616 - iou: 0.9261 - precision: 0.9611 - recall: 0.9623 - val_loss: 0.1450 - val_accuracy: 0.9437 - val_dice_coefficient: 0.9533 - val_iou: 0.9110 - val_precision: 0.9629 - val_recall: 0.9443
# Epoch 24/25
# 80/80 [==============================] - 19s 241ms/step - loss: 0.0975 - accuracy: 0.9601 - dice_coefficient: 0.9649 - iou: 0.9322 - precision: 0.9648 - recall: 0.9651 - val_loss: 0.1435 - val_accuracy: 0.9482 - val_dice_coefficient: 0.9588 - val_iou: 0.9211 - val_precision: 0.9518 - val_recall: 0.9664
# Epoch 25/25
# 80/80 [==============================] - 20s 252ms/step - loss: 0.0934 - accuracy: 0.9620 - dice_coefficient: 0.9665 - iou: 0.9352 - precision: 0.9666 - recall: 0.9665 - val_loss: 0.1386 - val_accuracy: 0.9471 - val_dice_coefficient: 0.9566 - val_iou: 0.9170 - val_precision: 0.9556 - val_recall: 0.9580

# %%
cunet_model.save("cunet_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
sample_batch = next(iter(test_batches))
random_index = np.random.choice(sample_batch[0].shape[0])
sample_image, sample_mask = sample_batch[0][random_index], sample_batch[1][random_index]
sample_image_batch = np.expand_dims(sample_image, axis=0)
pred = cunet_model.predict(sample_image_batch)
image = np.squeeze(pred, axis=0)
display([sample_image, sample_mask, image])
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
def plot_metrics(history):
    # Extract metrics from history
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    dice_coefficient = history.history['dice_coefficient']
    val_dice_coefficient = history.history['val_dice_coefficient']
    iou = history.history['iou']
    val_iou = history.history['val_iou']
    precision = history.history['precision']
    val_precision = history.history['val_precision']
    recall = history.history['recall']
    val_recall = history.history['val_recall']
    fig, axs = plt.subplots(2, 3, figsize=(15, 10))

    axs[0, 0].plot(loss, label='Training Loss')
    axs[0, 0].plot(val_loss, label='Validation Loss')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].set_ylabel('Loss')
    axs[0, 0].set_title('Training and Validation Loss')
    axs[0, 0].legend()

    axs[0, 1].plot(accuracy, label='Training Accuracy')
    axs[0, 1].plot(val_accuracy, label='Validation Accuracy')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].set_ylabel('Accuracy')
    axs[0, 1].set_title('Training and Validation Accuracy')
    axs[0, 1].legend()

    axs[0, 2].plot(dice_coefficient, label='Training Dice Coefficient')
    axs[0, 2].plot(val_dice_coefficient, label='Validation Dice Coefficient')
    axs[0, 2].set_xlabel('Epoch')
    axs[0, 2].set_ylabel('Dice Coefficient')
    axs[0, 2].set_title('Training and Validation Dice Coefficient')
    axs[0, 2].legend()

    axs[1, 0].plot(iou, label='Training IoU')
    axs[1, 0].plot(val_iou, label='Validation IoU')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].set_ylabel('IoU')
    axs[1, 0].set_title('Training and Validation IoU Coefficient')
    axs[1, 0].legend()

    axs[1, 1].plot(precision, label='Training Precision')
    axs[1, 1].plot(val_precision, label='Validation Precision')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].set_ylabel('Precision')
    axs[1, 1].set_title('Training and Validation Precision')
    axs[1, 1].legend()

    axs[1, 2].plot(recall, label='Training Recall')
    axs[1, 2].plot(val_recall, label='Validation Recall')
    axs[1, 2].set_xlabel('Epoch')
    axs[1, 2].set_ylabel('Recall')
    axs[1, 2].set_title('Training and Validation Recall')
    axs[1, 2].legend()

    plt.tight_layout()

    plt.savefig("metrics.png")
    plt.show()

plot_metrics(model_history)

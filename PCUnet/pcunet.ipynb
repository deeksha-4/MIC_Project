# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import layers
import numpy as np
from tqdm import tqdm
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
images_dir = '/content/drive/MyDrive/dataset/images'
masks_dir = '/content/drive/MyDrive/dataset/masks'

# %%
def PDC(input_layer):
  conv1 = tf.keras.layers.Conv2D(filters=32, kernel_size=(1, 1), dilation_rate=1, activation='relu', padding='same')(input_layer)
  conv2 = tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), dilation_rate=2, activation='relu', padding='same')(input_layer)
  conv3 = tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), dilation_rate=4, activation='relu', padding='same')(input_layer)
  conv4 = tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), dilation_rate=8, activation='relu', padding='same')(input_layer)
  concatenated_layers = tf.keras.layers.concatenate([conv1, conv2, conv3, conv4], axis=-1)
  output_layer = tf.keras.layers.Conv2D(filters=64, kernel_size=(1, 1), activation='relu', padding='same')(concatenated_layers)
  output_layer = tf.keras.layers.BatchNormalization()(output_layer)
  return output_layer

def gelu(x):
  return 0.5 * x * (1 + tf.math.erf(x / tf.sqrt(2.0)))

def ConvMixer(x,n_filters):
  depthwise_conv = tf.keras.layers.DepthwiseConv2D(kernel_size=(7, 7), padding='same')(x)
  gelu_activation = tf.keras.layers.Lambda(lambda y: gelu(y))(depthwise_conv)
  z_ = tf.keras.layers.BatchNormalization()(gelu_activation)
  z_input = tf.keras.layers.Add()([z_,x])
  pointwise_conv = tf.keras.layers.Conv2D(filters=64, kernel_size=(1, 1), activation=None, padding='same')(z_input)
  gelu_activation_2 = tf.keras.layers.Lambda(lambda y: gelu(y))(pointwise_conv)
  output_layer = tf.keras.layers.BatchNormalization()(gelu_activation_2)
  return output_layer

def conv_mixer_block(x, n_filters):
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = ConvMixer(x,n_filters)
  x = ConvMixer(x,n_filters)
  p = layers.MaxPool2D(2)(x)
  p = layers.Dropout(0.3)(p)
  return x,p

def pdcmodule(x, n_filters):
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = PDC(x)
  p = layers.MaxPool2D(2)(x)
  p = layers.Dropout(0.3)(p)
  return x,p

def double_conv_block(x, n_filters):
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  return x

def upsample_block(x, conv_features, n_filters):
  x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
  x = layers.concatenate([x, conv_features])
  x = layers.Dropout(0.3)(x)
  x = double_conv_block(x, n_filters)
  return x

def bottle(x,n_filters):
  x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = ConvMixer(x,n_filters)
  x = ConvMixer(x,n_filters)
  return x

# %%
def build_pcunet_model():
  inputs = layers.Input(shape=(384, 384,3))
  f1, p1 = conv_mixer_block(inputs, 64)
  f2, p2 = conv_mixer_block(p1, 128)
  f3, p3 = conv_mixer_block(p2, 256)
  f4, p4 = pdcmodule(p3, 512)

  bottleneck = bottle(p4, 1024)

  u6 = upsample_block(bottleneck, f4, 512)
  u7 = upsample_block(u6, f3, 256)
  u8 = upsample_block(u7, f2, 128)
  u9 = upsample_block(u8, f1, 64)

  outputs = layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u9)

  pcunet_model = tf.keras.Model(inputs, outputs, name="PCU-Net")

  return pcunet_model

# %%
def dice_coefficient(y_true, y_pred):
  smooth = 1e-6  # Smoothing factor to avoid division by zero
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
  dice = (2. * intersection + smooth) / (union + smooth)
  return dice

def iou(y_true, y_pred):
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
  smooth = 1e-6
  return (intersection + smooth) / (union - intersection + smooth)

def precision(y_true, y_pred):
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
  smooth = 1e-6
  return (intersection + smooth) / (tf.reduce_sum(y_pred)+ smooth)

def recall(y_true, y_pred):
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
  smooth = 1e-6
  return (intersection + smooth) / (tf.reduce_sum(y_true)+ smooth)

# %%
pcunet_model = build_pcunet_model()
pcunet_model.compile(optimizer=tf.keras.optimizers.Adam(),
                   loss=tf.keras.losses.BinaryCrossentropy(),
                   metrics=["accuracy", dice_coefficient, iou, precision, recall])

# %%
tf.keras.utils.plot_model(pcunet_model, show_shapes=True, expand_nested=True, dpi=64)

# %%
def resize(input_image, input_mask):
   input_image = tf.image.resize(input_image, (384, 384), method="nearest")
   input_mask = tf.image.resize(input_mask, (384, 384), method="nearest")
   return input_image, input_mask

def augment(input_image, input_mask):
   if tf.random.uniform(()) > 0.5:
       # Random flipping of the image and mask
       input_image = tf.image.flip_left_right(input_image)
       input_mask = tf.image.flip_left_right(input_mask)
   return input_image, input_mask

def normalize(input_image, input_mask):
   input_image = tf.cast(input_image, tf.float32) / 255.0
   input_mask -= 255
   return input_image, input_mask

# %%
def load_image_and_mask(image_file, mask_file):
    image = tf.io.read_file(image_file)
    image = tf.image.decode_jpeg(image, channels=3)
    mask = tf.io.read_file(mask_file)
    mask = tf.image.decode_png(mask, channels=1)
    return image, mask

def load_image_train(image_file, mask_file):
    input_image, input_mask = load_image_and_mask(image_file, mask_file)
    input_image, input_mask = resize(input_image, input_mask)
    input_image, input_mask = augment(input_image, input_mask)
    input_image, input_mask = normalize(input_image, input_mask)
    return input_image, input_mask

def load_image_test(image_file, mask_file):
    input_image, input_mask = load_image_and_mask(image_file, mask_file)
    input_image, input_mask = resize(input_image, input_mask)
    input_image, input_mask = normalize(input_image, input_mask)
    return input_image, input_mask

# %%
image_files = sorted([os.path.join(images_dir, filename) for filename in os.listdir(images_dir)])
mask_files = sorted([os.path.join(masks_dir, filename) for filename in os.listdir(masks_dir)])

# 80:20 train:test ratio
split = int(0.2 * len(image_files))

train_dataset = tf.data.Dataset.from_tensor_slices((image_files[split:], mask_files[split:]))
train_dataset = train_dataset.map(load_image_train, num_parallel_calls=tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((image_files[:split], mask_files[:split]))
test_dataset = test_dataset.map(load_image_test, num_parallel_calls=tf.data.AUTOTUNE)

print("Number of training samples:", len(train_dataset))
print("Number of testing samples:", len(test_dataset))
# Out:
# Number of training samples: 962
# Number of testing samples: 240

# %%
BATCH_SIZE = 12
BUFFER_SIZE = 150
train_batches = train_dataset.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
train_batches = train_batches.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
validation_batches = test_dataset.batch(BATCH_SIZE)
test_batches = test_dataset.batch(BATCH_SIZE)

# %%
def display(display_list):
 plt.figure(figsize=(15, 15))

 title = ["Input Image", "True Mask", "Predicted Mask"]

 for i in range(len(display_list)):
   plt.subplot(1, len(display_list), i+1)
   plt.title(title[i])
   plt.imshow(tf.keras.utils.array_to_img(display_list[i]))
   plt.axis("off")
 plt.show()

sample_batch = next(iter(train_batches))
random_index = np.random.choice(sample_batch[0].shape[0])
sample_image, sample_mask = sample_batch[0][random_index], sample_batch[1][random_index]
display([sample_image, sample_mask])

# %%
NUM_EPOCHS = 30
TRAIN_LENGTH = len(train_dataset)
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE
TEST_LENTH = len(test_dataset)
VALIDATION_STEPS = TEST_LENTH // BATCH_SIZE
model_history = pcunet_model.fit(train_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                              validation_data=test_batches)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 26s 238ms/step - loss: 0.5674 - accuracy: 0.8189 - dice_coefficient: 0.8066 - iou: 0.6813 - precision: 0.8418 - recall: 0.7846 - val_loss: 0.4239 - val_accuracy: 0.8247 - val_dice_coefficient: 0.8316 - val_iou: 0.7122 - val_precision: 0.8355 - val_recall: 0.8291
# Epoch 2/30
# 80/80 [==============================] - 18s 225ms/step - loss: 0.3939 - accuracy: 0.8346 - dice_coefficient: 0.8485 - iou: 0.7375 - precision: 0.8492 - recall: 0.8491 - val_loss: 0.4169 - val_accuracy: 0.8247 - val_dice_coefficient: 0.8737 - val_iou: 0.7764 - val_precision: 0.8402 - val_recall: 0.9116
# Epoch 3/30
# 80/80 [==============================] - 19s 235ms/step - loss: 0.4144 - accuracy: 0.8379 - dice_coefficient: 0.8541 - iou: 0.7462 - precision: 0.8586 - recall: 0.8518 - val_loss: 0.3737 - val_accuracy: 0.8243 - val_dice_coefficient: 0.8441 - val_iou: 0.7304 - val_precision: 0.8960 - val_recall: 0.7994
# Epoch 4/30
# 80/80 [==============================] - 18s 228ms/step - loss: 0.2815 - accuracy: 0.8801 - dice_coefficient: 0.8943 - iou: 0.8097 - precision: 0.8955 - recall: 0.8951 - val_loss: 0.2698 - val_accuracy: 0.8846 - val_dice_coefficient: 0.9139 - val_iou: 0.8421 - val_precision: 0.8841 - val_recall: 0.9473
# Epoch 5/30
# 80/80 [==============================] - 18s 228ms/step - loss: 0.2132 - accuracy: 0.9117 - dice_coefficient: 0.9212 - iou: 0.8542 - precision: 0.9224 - recall: 0.9210 - val_loss: 0.1913 - val_accuracy: 0.9177 - val_dice_coefficient: 0.9335 - val_iou: 0.8756 - val_precision: 0.9151 - val_recall: 0.9534
# Epoch 6/30
# 80/80 [==============================] - 19s 242ms/step - loss: 0.1919 - accuracy: 0.9212 - dice_coefficient: 0.9303 - iou: 0.8698 - precision: 0.9297 - recall: 0.9315 - val_loss: 0.1903 - val_accuracy: 0.9233 - val_dice_coefficient: 0.9356 - val_iou: 0.8794 - val_precision: 0.9217 - val_recall: 0.9509
# Epoch 7/30
# 80/80 [==============================] - 18s 231ms/step - loss: 0.1736 - accuracy: 0.9272 - dice_coefficient: 0.9368 - iou: 0.8814 - precision: 0.9373 - recall: 0.9369 - val_loss: 0.1719 - val_accuracy: 0.9284 - val_dice_coefficient: 0.9365 - val_iou: 0.8809 - val_precision: 0.9226 - val_recall: 0.9515
# Epoch 8/30
# 80/80 [==============================] - 19s 244ms/step - loss: 0.1719 - accuracy: 0.9284 - dice_coefficient: 0.9372 - iou: 0.8821 - precision: 0.9367 - recall: 0.9385 - val_loss: 0.1866 - val_accuracy: 0.9273 - val_dice_coefficient: 0.9440 - val_iou: 0.8943 - val_precision: 0.9393 - val_recall: 0.9495
# Epoch 9/30
# 80/80 [==============================] - 20s 245ms/step - loss: 0.1636 - accuracy: 0.9340 - dice_coefficient: 0.9412 - iou: 0.8892 - precision: 0.9422 - recall: 0.9408 - val_loss: 0.1736 - val_accuracy: 0.9314 - val_dice_coefficient: 0.9416 - val_iou: 0.8899 - val_precision: 0.9311 - val_recall: 0.9531
# Epoch 10/30
# 80/80 [==============================] - 22s 281ms/step - loss: 0.1563 - accuracy: 0.9368 - dice_coefficient: 0.9436 - iou: 0.8934 - precision: 0.9444 - recall: 0.9432 - val_loss: 0.1660 - val_accuracy: 0.9344 - val_dice_coefficient: 0.9478 - val_iou: 0.9012 - val_precision: 0.9303 - val_recall: 0.9668
# Epoch 11/30
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1509 - accuracy: 0.9388 - dice_coefficient: 0.9468 - iou: 0.8992 - precision: 0.9467 - recall: 0.9474 - val_loss: 0.1724 - val_accuracy: 0.9312 - val_dice_coefficient: 0.9374 - val_iou: 0.8825 - val_precision: 0.9521 - val_recall: 0.9238
# Epoch 12/30
# 80/80 [==============================] - 19s 239ms/step - loss: 0.1618 - accuracy: 0.9341 - dice_coefficient: 0.9410 - iou: 0.8887 - precision: 0.9425 - recall: 0.9401 - val_loss: 0.1601 - val_accuracy: 0.9350 - val_dice_coefficient: 0.9456 - val_iou: 0.8970 - val_precision: 0.9333 - val_recall: 0.9586
# Epoch 13/30
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1416 - accuracy: 0.9415 - dice_coefficient: 0.9489 - iou: 0.9030 - precision: 0.9496 - recall: 0.9486 - val_loss: 0.1453 - val_accuracy: 0.9427 - val_dice_coefficient: 0.9527 - val_iou: 0.9099 - val_precision: 0.9515 - val_recall: 0.9544
# Epoch 14/30
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1399 - accuracy: 0.9422 - dice_coefficient: 0.9495 - iou: 0.9041 - precision: 0.9497 - recall: 0.9498 - val_loss: 0.1660 - val_accuracy: 0.9416 - val_dice_coefficient: 0.9517 - val_iou: 0.9081 - val_precision: 0.9378 - val_recall: 0.9666
# Epoch 15/30
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1322 - accuracy: 0.9474 - dice_coefficient: 0.9529 - iou: 0.9102 - precision: 0.9529 - recall: 0.9532 - val_loss: 0.1500 - val_accuracy: 0.9414 - val_dice_coefficient: 0.9479 - val_iou: 0.9012 - val_precision: 0.9433 - val_recall: 0.9531
# Epoch 16/30
# 80/80 [==============================] - 19s 242ms/step - loss: 0.1247 - accuracy: 0.9487 - dice_coefficient: 0.9551 - iou: 0.9141 - precision: 0.9548 - recall: 0.9556 - val_loss: 0.1515 - val_accuracy: 0.9457 - val_dice_coefficient: 0.9555 - val_iou: 0.9151 - val_precision: 0.9511 - val_recall: 0.9606
# Epoch 17/30
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1260 - accuracy: 0.9486 - dice_coefficient: 0.9548 - iou: 0.9136 - precision: 0.9554 - recall: 0.9545 - val_loss: 0.1586 - val_accuracy: 0.9430 - val_dice_coefficient: 0.9521 - val_iou: 0.9088 - val_precision: 0.9421 - val_recall: 0.9628
# Epoch 18/30
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1263 - accuracy: 0.9493 - dice_coefficient: 0.9551 - iou: 0.9141 - precision: 0.9550 - recall: 0.9555 - val_loss: 0.1350 - val_accuracy: 0.9475 - val_dice_coefficient: 0.9552 - val_iou: 0.9144 - val_precision: 0.9522 - val_recall: 0.9585
# Epoch 19/30
# 80/80 [==============================] - 20s 248ms/step - loss: 0.1182 - accuracy: 0.9517 - dice_coefficient: 0.9571 - iou: 0.9180 - precision: 0.9570 - recall: 0.9577 - val_loss: 0.1381 - val_accuracy: 0.9465 - val_dice_coefficient: 0.9554 - val_iou: 0.9148 - val_precision: 0.9566 - val_recall: 0.9546
# Epoch 20/30
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1154 - accuracy: 0.9525 - dice_coefficient: 0.9582 - iou: 0.9199 - precision: 0.9583 - recall: 0.9583 - val_loss: 0.1461 - val_accuracy: 0.9459 - val_dice_coefficient: 0.9554 - val_iou: 0.9150 - val_precision: 0.9472 - val_recall: 0.9644
# Epoch 21/30
# 80/80 [==============================] - 20s 248ms/step - loss: 0.1062 - accuracy: 0.9574 - dice_coefficient: 0.9620 - iou: 0.9269 - precision: 0.9616 - recall: 0.9627 - val_loss: 0.1378 - val_accuracy: 0.9471 - val_dice_coefficient: 0.9589 - val_iou: 0.9211 - val_precision: 0.9631 - val_recall: 0.9550
# Epoch 22/30
# 80/80 [==============================] - 20s 250ms/step - loss: 0.1064 - accuracy: 0.9569 - dice_coefficient: 0.9620 - iou: 0.9269 - precision: 0.9620 - recall: 0.9623 - val_loss: 0.1463 - val_accuracy: 0.9481 - val_dice_coefficient: 0.9593 - val_iou: 0.9220 - val_precision: 0.9521 - val_recall: 0.9670
# Epoch 23/30
# 80/80 [==============================] - 19s 241ms/step - loss: 0.1008 - accuracy: 0.9586 - dice_coefficient: 0.9636 - iou: 0.9298 - precision: 0.9642 - recall: 0.9632 - val_loss: 0.1401 - val_accuracy: 0.9481 - val_dice_coefficient: 0.9576 - val_iou: 0.9189 - val_precision: 0.9478 - val_recall: 0.9681
# Epoch 24/30
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0966 - accuracy: 0.9608 - dice_coefficient: 0.9654 - iou: 0.9332 - precision: 0.9650 - recall: 0.9660 - val_loss: 0.1452 - val_accuracy: 0.9469 - val_dice_coefficient: 0.9585 - val_iou: 0.9204 - val_precision: 0.9590 - val_recall: 0.9583
# Epoch 25/30
# 80/80 [==============================] - 20s 250ms/step - loss: 0.0929 - accuracy: 0.9620 - dice_coefficient: 0.9665 - iou: 0.9352 - precision: 0.9664 - recall: 0.9666 - val_loss: 0.1403 - val_accuracy: 0.9465 - val_dice_coefficient: 0.9574 - val_iou: 0.9185 - val_precision: 0.9636 - val_recall: 0.9517
# Epoch 26/30
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0890 - accuracy: 0.9637 - dice_coefficient: 0.9679 - iou: 0.9378 - precision: 0.9680 - recall: 0.9679 - val_loss: 0.1517 - val_accuracy: 0.9494 - val_dice_coefficient: 0.9607 - val_iou: 0.9247 - val_precision: 0.9503 - val_recall: 0.9719
# Epoch 27/30
# 80/80 [==============================] - 20s 251ms/step - loss: 0.0849 - accuracy: 0.9651 - dice_coefficient: 0.9693 - iou: 0.9404 - precision: 0.9694 - recall: 0.9693 - val_loss: 0.1378 - val_accuracy: 0.9519 - val_dice_coefficient: 0.9624 - val_iou: 0.9276 - val_precision: 0.9587 - val_recall: 0.9665
# Epoch 28/30
# 80/80 [==============================] - 20s 251ms/step - loss: 0.0901 - accuracy: 0.9636 - dice_coefficient: 0.9674 - iou: 0.9369 - precision: 0.9671 - recall: 0.9679 - val_loss: 0.1416 - val_accuracy: 0.9500 - val_dice_coefficient: 0.9604 - val_iou: 0.9241 - val_precision: 0.9544 - val_recall: 0.9670
# Epoch 29/30
# 80/80 [==============================] - 20s 250ms/step - loss: 0.0845 - accuracy: 0.9651 - dice_coefficient: 0.9693 - iou: 0.9406 - precision: 0.9694 - recall: 0.9694 - val_loss: 0.1479 - val_accuracy: 0.9492 - val_dice_coefficient: 0.9607 - val_iou: 0.9246 - val_precision: 0.9568 - val_recall: 0.9651
# Epoch 30/30
# 80/80 [==============================] - 19s 241ms/step - loss: 0.0802 - accuracy: 0.9673 - dice_coefficient: 0.9712 - iou: 0.9440 - precision: 0.9715 - recall: 0.9710 - val_loss: 0.1530 - val_accuracy: 0.9479 - val_dice_coefficient: 0.9613 - val_iou: 0.9257 - val_precision: 0.9600 - val_recall: 0.9631

# %%
pcunet_model.save("pcunet_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
sample_batch = next(iter(test_batches))
random_index = np.random.choice(sample_batch[0].shape[0])
sample_image, sample_mask = sample_batch[0][random_index], sample_batch[1][random_index]
sample_image_batch = np.expand_dims(sample_image, axis=0)
pred = pcunet_model.predict(sample_image_batch)
image = np.squeeze(pred, axis=0)
display([sample_image, sample_mask, image])
# Out:
# 1/1 [==============================] - 0s 235ms/step

# %%
def plot_metrics(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    dice_coefficient = history.history['dice_coefficient']
    val_dice_coefficient = history.history['val_dice_coefficient']
    iou = history.history['iou']
    val_iou = history.history['val_iou']
    precision = history.history['precision']
    val_precision = history.history['val_precision']
    recall = history.history['recall']
    val_recall = history.history['val_recall']

    fig, axs = plt.subplots(2, 3, figsize=(15, 10))

    axs[0, 0].plot(loss, label='Training Loss')
    axs[0, 0].plot(val_loss, label='Validation Loss')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].set_ylabel('Loss')
    axs[0, 0].set_title('Training and Validation Loss')
    axs[0, 0].legend()

    axs[0, 1].plot(accuracy, label='Training Accuracy')
    axs[0, 1].plot(val_accuracy, label='Validation Accuracy')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].set_ylabel('Accuracy')
    axs[0, 1].set_title('Training and Validation Accuracy')
    axs[0, 1].legend()

    axs[0, 2].plot(dice_coefficient, label='Training Dice Coefficient')
    axs[0, 2].plot(val_dice_coefficient, label='Validation Dice Coefficient')
    axs[0, 2].set_xlabel('Epoch')
    axs[0, 2].set_ylabel('Dice Coefficient')
    axs[0, 2].set_title('Training and Validation Dice Coefficient')
    axs[0, 2].legend()

    axs[1, 0].plot(iou, label='Training IoU')
    axs[1, 0].plot(val_iou, label='Validation IoU')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].set_ylabel('IoU')
    axs[1, 0].set_title('Training and Validation IoU Coefficient')
    axs[1, 0].legend()

    axs[1, 1].plot(precision, label='Training Precision')
    axs[1, 1].plot(val_precision, label='Validation Precision')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].set_ylabel('Precision')
    axs[1, 1].set_title('Training and Validation Precision')
    axs[1, 1].legend()

    axs[1, 2].plot(recall, label='Training Recall')
    axs[1, 2].plot(val_recall, label='Validation Recall')
    axs[1, 2].set_xlabel('Epoch')
    axs[1, 2].set_ylabel('Recall')
    axs[1, 2].set_title('Training and Validation Recall')
    axs[1, 2].legend()

    plt.tight_layout()

    plt.savefig("pcu_metrics.png")
    plt.show()

plot_metrics(model_history)
